# %%
from tensorflow.keras.models import load_model

# %%
model_sentiment = load_model('../models/sentiment/sentiment_model-v2.h5')

# %%
import pydot
from tensorflow.keras.utils import plot_model
plot_model(model_sentiment, to_file='sentiment.png', show_shapes=True)

# %%
model_news = load_model('../models/news/news_model.h5')

# %%
plot_model(model_news, to_file='news.png', show_shapes=True)

# %%
model_spam = load_model('../models/spam/spam_model.h5')

# %%
plot_model(model_spam, to_file='spam.png', show_shapes=True)
